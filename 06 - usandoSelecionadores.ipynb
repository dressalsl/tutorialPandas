# %% [markdown]
# ##Importando o Pandas e o leitor de url

# %%
import pandas as pd
import io
import requests

# %% [markdown]
# ##Lendo a url do arquivo csv

# %%
url = "https://raw.githubusercontent.com/dressalsl/tutorialPandas/master/dataSets/bank.csv"
df = pd.read_csv(url, sep=';')
df.head()
# Out:
#    age          job  marital  education  ... pdays  previous poutcome   y
# 0   30   unemployed  married    primary  ...    -1         0  unknown  no
# 1   33     services  married  secondary  ...   339         4  failure  no
# 2   35   management   single   tertiary  ...   330         1  failure  no
# 3   30   management  married   tertiary  ...    -1         0  unknown  no
# 4   59  blue-collar  married  secondary  ...    -1         0  unknown  no
#
# [5 rows x 17 columns]

# %% [markdown]
# ## Ordenando pela duração de chamada

# %%
df.sort_values(by='duration').head()
# Out:
#       age          job   marital  education  ... pdays  previous poutcome   y
# 1116   28   management   married   tertiary  ...    -1         0  unknown  no
# 1106   35  blue-collar   married  secondary  ...   808        12  failure  no
# 2280   29   management    single  secondary  ...    -1         0  unknown  no
# 3566   35     services   married  secondary  ...    -1         0  unknown  no
# 462    45   management  divorced   tertiary  ...    -1         0  unknown  no
#
# [5 rows x 17 columns]

# %% [markdown]
# ## Ordenando de A-Z por profissões

# %%
df.sort_values(by='job').head()
# Out:
#       age     job   marital  education  ... pdays  previous poutcome   y
# 3879   25  admin.    single   tertiary  ...    -1         0  unknown  no
# 3559   36  admin.    single  secondary  ...    -1         0  unknown  no
# 4244   39  admin.  divorced  secondary  ...    -1         0  unknown  no
# 2365   33  admin.  divorced  secondary  ...   173         2    other  no
# 4240   45  admin.   married  secondary  ...    -1         0  unknown  no
#
# [5 rows x 17 columns]

# %% [markdown]
# ## Apresenta os maiores valores de cada coluna

# %%
df.max()
# Out:
# age               87
# job          unknown
# marital       single
# education    unknown
# default          yes
# balance        71188
# housing          yes
# loan             yes
# contact      unknown
# day               31
# month            sep
# duration        3025
# campaign          50
# pdays            871
# previous          25
# poutcome     unknown
# y                yes
# dtype: object

# %% [markdown]
# ## Apresenta os menores valores de cada coluna

# %%
df.min()
# Out:
# age                19
# job            admin.
# marital      divorced
# education     primary
# default            no
# balance         -3313
# housing            no
# loan               no
# contact      cellular
# day                 1
# month             apr
# duration            4
# campaign            1
# pdays              -1
# previous            0
# poutcome      failure
# y                  no
# dtype: object

# %% [markdown]
# ## Faz a transposição da visualização dos dados do DataFrame

# %%
df.T
# Out:
#                  0          1     ...         4519          4520
# age                30         33  ...           28            44
# job        unemployed   services  ...  blue-collar  entrepreneur
# marital       married    married  ...      married        single
# education     primary  secondary  ...    secondary      tertiary
# default            no         no  ...           no            no
# balance          1787       4789  ...         1137          1136
# housing            no        yes  ...           no           yes
# loan               no        yes  ...           no           yes
# contact      cellular   cellular  ...     cellular      cellular
# day                19         11  ...            6             3
# month             oct        may  ...          feb           apr
# duration           79        220  ...          129           345
# campaign            1          1  ...            4             2
# ...

# %% [markdown]
# ## Visualização do DataFrame

# %%
df.head()
# Out:
#    age          job  marital  education  ... pdays  previous poutcome   y
# 0   30   unemployed  married    primary  ...    -1         0  unknown  no
# 1   33     services  married  secondary  ...   339         4  failure  no
# 2   35   management   single   tertiary  ...   330         1  failure  no
# 3   30   management  married   tertiary  ...    -1         0  unknown  no
# 4   59  blue-collar  married  secondary  ...    -1         0  unknown  no
#
# [5 rows x 17 columns]

# %% [markdown]
# ## Selecionando pelo operador ==

# %%
df[df.month == "jan"].head()
# Out:
#      age          job  marital  education  ... pdays  previous poutcome    y
# 14    31  blue-collar  married  secondary  ...   241         1  failure   no
# 24    26    housemaid  married   tertiary  ...    -1         0  unknown   no
# 49    61       admin.  married    unknown  ...    92         1  success  yes
# 66    31     services  married  secondary  ...    -1         0  unknown   no
# 113   33  blue-collar   single  secondary  ...   207         1  failure   no
#
# [5 rows x 17 columns]

# %% [markdown]
# ## Selecionando pelo operador E

# %%
df[(df.month == "jan") & (df.contact == "cellular")].head()
# Out:
#      age          job  marital  education  ... pdays  previous poutcome    y
# 14    31  blue-collar  married  secondary  ...   241         1  failure   no
# 24    26    housemaid  married   tertiary  ...    -1         0  unknown   no
# 49    61       admin.  married    unknown  ...    92         1  success  yes
# 66    31     services  married  secondary  ...    -1         0  unknown   no
# 113   33  blue-collar   single  secondary  ...   207         1  failure   no
#
# [5 rows x 17 columns]

# %% [markdown]
# ## Selecionando pelo operador OU

# %%
df[(df.marital == "single") & ((df.education == "primary") | (df.education == "secondary"))].head()
# Out:
#     age           job marital  education  ... pdays  previous poutcome    y
# 13   20       student  single  secondary  ...    -1         0  unknown  yes
# 18   25   blue-collar  single    primary  ...    -1         0  unknown   no
# 22   44      services  single  secondary  ...    -1         0  unknown   no
# 48   32  entrepreneur  single    primary  ...    -1         0  unknown   no
# 51   37    technician  single  secondary  ...    -1         0  unknown   no
#
# [5 rows x 17 columns]

# %% [markdown]
# # #*Exercício:*
# ###a) Na coluna month selecione apenas o mês de abril
# ###b) Na coluna job selecione student e na coluna marital selecione single
# ###c) Na coluna education selecione primary ou secondary

# %%
#a)

# %%
#b)

# %%
#c)
