# %% [markdown]
# ##Importando a biblioteca do Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Abrindo arquivo por URL
#
# ### Importando leitor de url

# %%
import io
import requests

# %% [markdown]
# ## Lendo a url do arquivo csv

# %%
url = "https://raw.githubusercontent.com/dressalsl/tutorialPandas/master/dataSets/brazil-microcephaly-2016-01-23-table-1.csv"
df1 = pd.read_csv(url, sep=',')

# %% [markdown]
# ##Visualizar o dataset

# %%
df1.head()
# Out:
#    no     state  ... cases_discarded cases_reported_total
# 0   1   Alagoas  ...               0                  158
# 1   2     Bahia  ...              27                  533
# 2   3     Ceará  ...               7                  229
# 3   4  Maranhão  ...              15                  134
# 4   5   Paraíba  ...             181                  709
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Abrindo um arquivo local (coloque o caminho do seu arquivo para abri-lo)

# %%
df2 = pd.read_csv(r"C:\Users\Andressa\Documents\data project\dataSets\bank.csv", encoding = "UTF-8")

# %% [markdown]
# ##Abrindo arquivo pelo Google Colab

# %%
from google.colab import files 
up = files.upload()
# Out:
#      <input type="file" id="files-c76198e0-e362-4cc3-bafc-d356ce1159d7" name="files[]" multiple disabled />
#      <output id="result-c76198e0-e362-4cc3-bafc-d356ce1159d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# # #*Exercício:*
#
# ###a) Com o link abaixo leia uma url de um dataset e visualize ele usando a função head()
# ####Link (Datasets free) : https://github.com/fivethirtyeight/data
# ####Dataset > arquivo.csv > raw > copy url

# %%
#a)
