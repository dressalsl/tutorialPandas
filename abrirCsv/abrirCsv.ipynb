# %%
# importando o pandas
import pandas as pd

# %%
# Lendo o arquivo CSV
df = pd.read_csv(r"C:\Users\Andressa\Documents\data project\abrirCsv\brazil-microcephaly-2016-01-23-table-1.csv", encoding = "UTF-8")

# %%
# Apresenta as 05 primeiras linhas do DataFrame
df.head()
# Out:
#    no     state cases_under_investigation cases_confirmed cases_discarded  \
# 0   1   Alagoas                       158               0               0
# 1   2     Bahia                       471              35              27
# 2   3     Ceará                       218               4               7
# 3   4  Maranhão                       119               0              15
# 4   5   Paraíba                       497              31             181
#
#   cases_reported_total
# 0                  158
# 1                  533
# 2                  229
# 3                  134
# 4                  709

# %%
# Para exibir um número X de linhas, basta definir o paramêtro
df.head(n=10)
# Out:
#    no                state cases_under_investigation cases_confirmed  \
# 0   1              Alagoas                       158               0
# 1   2                Bahia                       471              35
# 2   3                Ceará                       218               4
# 3   4             Maranhão                       119               0
# 4   5              Paraíba                       497              31
# 5   6           Pernambuco                      1125             138
# 6   7                Piauí                        91               0
# 7   8  Rio Grande do Norte                       133              60
# 8   9              Sergipe                       172               0
# 9  10       Espírito Santo                        52               0
#
#   cases_discarded cases_reported_total
# 0               0                  158
# 1              27                  533
# 2               7                  229
# 3              15                  134
# 4             181                  709
# 5             110                 1373
# 6               0                   91
# 7              15                  208
# 8               0                  172
# 9               0                   52

# %%
# Apresenta as 05 últimas linhas do DataFrame
df.tail()
# Out:
#     no               state cases_under_investigation cases_confirmed  \
# 22  23         Mato Grosso                       110               0
# 23  24  Mato Grosso do Sul                         3               0
# 24  25              Paraná                         2               0
# 25  26      Santa Catarina                         0               0
# 26  27   Rio Grande do Sul                         0               1
#
#    cases_discarded cases_reported_total
# 22              37                  147
# 23               1                    4
# 24               8                   10
# 25               1                    1
# 26               0                    1

# %%
# Indica o número de linhas x colunas do DataFrame
df.shape
# Out:
# (27, 6)

# %%
# Descrição do Index
df.index
# Out:
# RangeIndex(start=0, stop=27, step=1)

# %%
# Apresenta as colunas do DataFrame
df.columns
# Out:
# Index(['no', 'state', 'cases_under_investigation', 'cases_confirmed',
#        'cases_discarded', 'cases_reported_total'],
#       dtype='object')

# %%
# Apresenta a quantidade de dados não-nulos
df.count()
# Out:
# no                           27
# state                        27
# cases_under_investigation    27
# cases_confirmed              27
# cases_discarded              27
# cases_reported_total         27
# dtype: int64
