# %% [markdown]
# ## Importando o pandas e o leitor de url

# %%
import pandas as pd
import io
import requests

# %% [markdown]
# ## Lendo a url do arquivo csv

# %%
url = "https://raw.githubusercontent.com/dressalsl/tutorialPandas/master/dataSets/brazil-microcephaly-2016-01-23-table-1.csv"
df = pd.read_csv(url, sep=',')

# %% [markdown]
# ## Apresenta as 05 primeiras linhas do DataFrame

# %%
df.head()
# Out:
#    no     state  ... cases_discarded cases_reported_total
# 0   1   Alagoas  ...               0                  158
# 1   2     Bahia  ...              27                  533
# 2   3     Ceará  ...               7                  229
# 3   4  Maranhão  ...              15                  134
# 4   5   Paraíba  ...             181                  709
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Para exibir um número X de linhas, basta definir o paramêtro

# %%
df.head(n=10)
# Out:
#    no                state  ... cases_discarded cases_reported_total
# 0   1              Alagoas  ...               0                  158
# 1   2                Bahia  ...              27                  533
# 2   3                Ceará  ...               7                  229
# 3   4             Maranhão  ...              15                  134
# 4   5              Paraíba  ...             181                  709
# 5   6           Pernambuco  ...             110                 1373
# 6   7                Piauí  ...               0                   91
# 7   8  Rio Grande do Norte  ...              15                  208
# 8   9              Sergipe  ...               0                  172
# 9  10       Espírito Santo  ...               0                   52
#
# [10 rows x 6 columns]

# %% [markdown]
# ## Apresenta as 05 últimas linhas do DataFrame

# %%
df.tail()
# Out:
#     no               state  ... cases_discarded cases_reported_total
# 22  23         Mato Grosso  ...              37                  147
# 23  24  Mato Grosso do Sul  ...               1                    4
# 24  25              Paraná  ...               8                   10
# 25  26      Santa Catarina  ...               1                    1
# 26  27   Rio Grande do Sul  ...               0                    1
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Indica o número de linhas x colunas do DataFrame

# %%
df.shape
# Out:
# (27, 6)

# %% [markdown]
# ## Descrição do Index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=27, step=1)

# %% [markdown]
# ## Apresenta as colunas do DataFrame

# %%
df.columns
# Out:
# Index(['no', 'state', 'cases_under_investigation', 'cases_confirmed',
#        'cases_discarded', 'cases_reported_total'],
#       dtype='object')

# %% [markdown]
# ## Apresenta a quantidade de dados não-nulos

# %%
df.count()
# Out:
# no                           27
# state                        27
# cases_under_investigation    27
# cases_confirmed              27
# cases_discarded              27
# cases_reported_total         27
# dtype: int64

# %% [markdown]
# ## Inverter a ordem das colunas

# %%
df[:-1]
# Out:
#     no                state  ... cases_discarded cases_reported_total
# 0    1              Alagoas  ...               0                  158
# 1    2                Bahia  ...              27                  533
# 2    3                Ceará  ...               7                  229
# 3    4             Maranhão  ...              15                  134
# 4    5              Paraíba  ...             181                  709
# 5    6           Pernambuco  ...             110                 1373
# 6    7                Piauí  ...               0                   91
# 7    8  Rio Grande do Norte  ...              15                  208
# 8    9              Sergipe  ...               0                  172
# 9   10       Espírito Santo  ...               0                   52
# 10  11         Minas Gerais  ...              39                   48
# 11  12       Rio de Janeiro  ...               0                  122
# 12  13            São Paulo  ...               0                   18
# 13  14                 Acre  ...   Sem registros       Sem registros
# 14  15                Amapá  ...   Sem registros       Sem registros
# 15  16             Amazonas  ...   Sem registros       Sem registros
# 16  17                 Pará  ...               0                    6
# 17  18             Rondônia  ...               0                    1
# 18  19              Roraima  ...               0                    5
# 19  20            Tocantins  ...              12                   82
# 20  21     Distrito Federal  ...               9                   14
# 21  22                Goiás  ...               0                   62
# 22  23          Mato Grosso  ...              37                  147
# 23  24   Mato Grosso do Sul  ...               1                    4
# 24  25               Paraná  ...               8                   10
# 25  26       Santa Catarina  ...               1                    1
#
# [26 rows x 6 columns]

# %% [markdown]
# ## Verificar o tipo dos valores da coluna do Data Frame

# %%
df.dtypes
# Out:
# no                            int64
# state                        object
# cases_under_investigation    object
# cases_confirmed              object
# cases_discarded              object
# cases_reported_total         object
# dtype: object

# %% [markdown]
# # #*Exercício:*
#
# ###Com o dataset usado no exercicio passado faça:
# ###a) Use shape
# ###b) Use columns
# ###c) Use count()
# ###d) Inverta a ordem das colunas
# ####* Crie uma variavél
